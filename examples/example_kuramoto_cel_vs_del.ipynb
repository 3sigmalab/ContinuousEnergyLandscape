# %% [markdown]
# # Kuramoto example: Continuous vs Discrete Energy Landscape
#
# This notebook simulates BOLD-like signals from a Kuramoto + hemodynamic
# model, then compares discrete vs continuous energy landscape approaches
# for recovering hidden regimes.

# %%
import os, sys

sys.path.append(os.path.abspath(".."))


import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

from continuous_energy_landscape import ContinuousEnergyLandscape
from simulations.kuramoto_sim_simple import simulate_kuramoto_example
from metrics_energy_landscape import compute_metrics_all
from discrete_energy import binarize, ener_calculate_pca_bin
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2c/9sz68k7d0h7gh6kzgm3hyh4w0000gn/T/ipykernel_18532/3727554908.py", line 10, in <module>
#     from continuous_energy_landscape import ContinuousEnergyLandscape
#   File "/Users/tranminhtriet/Documents/Desktop/OU/DSA/Energy_Landscape/ContinuousEnergyLandscape/continuous_energy_landscape.py", line 3, in <module>
#     import torch
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),

# %% [markdown]
# ## 1. Simulate Kuramoto-BOLD data

# %%
K = 3
d = 12    
T = 3000
seed = 0

sim, X, g_true = simulate_kuramoto_example(
    K=K,
    d=d,
    T=T,
    dwell=160,   # slightly longer dwell
    sigma=0.6,   # keep some noise
    seed=seed,
)

P_true = sim.P
print("X shape:", X.shape)
print("g_true shape:", g_true.shape)
# Out:
# X shape: (3000, 12)
# g_true shape: (3000,)

# %% [markdown]
# ## 2. Discrete energy landscape (DEL) baseline
#
# As in the SLDS example, we fit an Ising model on binarized data and
#             cluster the resulting energy time series.

# %%
X_bin = binarize(X.T)
h_del, W_del, E_del = ener_calculate_pca_bin(X_bin)
print("Discrete energy shape:", E_del.shape)

E_feat = E_del.reshape(-1, 1)
km_del = KMeans(n_clusters=K, random_state=seed)
g_del = km_del.fit_predict(E_feat)
print("DEL labels shape:", g_del.shape)
# Out:
# [MEM] it=  200 max|mom-res|=3.361e-01, step=0.2
# [MEM] it=  400 max|mom-res|=3.369e-01, step=0.197
# [MEM] it=  600 max|mom-res|=3.326e-01, step=0.194
# [MEM] it=  800 max|mom-res|=3.264e-01, step=0.191
# [MEM] it= 1000 max|mom-res|=3.209e-01, step=0.188
# [MEM] it= 1200 max|mom-res|=3.153e-01, step=0.185
# [MEM] it= 1400 max|mom-res|=3.085e-01, step=0.183
# [MEM] it= 1600 max|mom-res|=2.902e-01, step=0.18
# [MEM] it= 1800 max|mom-res|=2.710e-01, step=0.177
# [MEM] it= 2000 max|mom-res|=2.339e-01, step=0.175
# [MEM] it= 2200 max|mom-res|=1.880e-01, step=0.172
# [MEM] it= 2400 max|mom-res|=1.242e-01, step=0.169
# [MEM] it= 2600 max|mom-res|=1.376e-02, step=0.167
# [MEM] it= 2800 max|mom-res|=8.297e-04, step=0.164
# [MEM] it= 3000 max|mom-res|=7.703e-04, step=0.162
# [MEM] it= 3200 max|mom-res|=7.159e-04, step=0.159
# [MEM] it= 3400 max|mom-res|=6.673e-04, step=0.157
# [MEM] it= 3600 max|mom-res|=6.240e-04, step=0.155
# [MEM] it= 3800 max|mom-res|=5.855e-04, step=0.152
# [MEM] it= 4000 max|mom-res|=5.511e-04, step=0.15
# [MEM] it= 4200 max|mom-res|=5.204e-04, step=0.148
# [MEM] it= 4400 max|mom-res|=4.929e-04, step=0.146
# [MEM] it= 4600 max|mom-res|=4.682e-04, step=0.143
# [MEM] it= 4800 max|mom-res|=4.459e-04, step=0.141
# [MEM] it= 5000 max|mom-res|=4.258e-04, step=0.139
# [MEM] it= 5200 max|mom-res|=4.076e-04, step=0.137
# [MEM] it= 5400 max|mom-res|=3.910e-04, step=0.135
# [MEM] it= 5600 max|mom-res|=3.758e-04, step=0.133
# [MEM] it= 5800 max|mom-res|=3.619e-04, step=0.131
# [MEM] it= 6000 max|mom-res|=3.492e-04, step=0.129
# [MEM] it= 6200 max|mom-res|=3.374e-04, step=0.127
# [MEM] it= 6400 max|mom-res|=3.266e-04, step=0.125
# [MEM] it= 6600 max|mom-res|=3.166e-04, step=0.123
# [MEM] it= 6800 max|mom-res|=3.073e-04, step=0.121
# [MEM] it= 7000 max|mom-res|=2.986e-04, step=0.12
# [MEM] it= 7200 max|mom-res|=2.906e-04, step=0.118
# [MEM] it= 7400 max|mom-res|=2.830e-04, step=0.116
# [MEM] it= 7600 max|mom-res|=2.760e-04, step=0.114
# [MEM] it= 7800 max|mom-res|=2.694e-04, step=0.113
# [MEM] it= 8000 max|mom-res|=2.632e-04, step=0.111
# [MEM] it= 8200 max|mom-res|=2.574e-04, step=0.109
# [MEM] it= 8400 max|mom-res|=2.518e-04, step=0.108
# [MEM] it= 8600 max|mom-res|=2.467e-04, step=0.106
# [MEM] it= 8800 max|mom-res|=2.417e-04, step=0.104
# [MEM] it= 9000 max|mom-res|=2.371e-04, step=0.103
# [MEM] it= 9200 max|mom-res|=2.327e-04, step=0.101
# [MEM] it= 9400 max|mom-res|=2.285e-04, step=0.0998
# [MEM] it= 9600 max|mom-res|=2.245e-04, step=0.0983
# [MEM] it= 9800 max|mom-res|=2.208e-04, step=0.0968
# [MEM] it=10000 max|mom-res|=2.172e-04, step=0.0954
# [MEM] it=10200 max|mom-res|=2.137e-04, step=0.0939
# [MEM] it=10400 max|mom-res|=2.105e-04, step=0.0925
# [MEM] it=10600 max|mom-res|=2.073e-04, step=0.0911
# [MEM] it=10800 max|mom-res|=2.043e-04, step=0.0898
# [MEM] it=11000 max|mom-res|=2.015e-04, step=0.0884
# [MEM] it=11200 max|mom-res|=1.987e-04, step=0.0871
# [MEM] it=11400 max|mom-res|=1.961e-04, step=0.0858
# [MEM] it=11600 max|mom-res|=1.936e-04, step=0.0845
# [MEM] it=11800 max|mom-res|=1.912e-04, step=0.0832
# [MEM] it=12000 max|mom-res|=1.888e-04, step=0.082
# [MEM] it=12200 max|mom-res|=1.866e-04, step=0.0808
# [MEM] it=12400 max|mom-res|=1.844e-04, step=0.0795
# [MEM] it=12600 max|mom-res|=1.824e-04, step=0.0784
# [MEM] it=12800 max|mom-res|=1.804e-04, step=0.0772
# [MEM] it=13000 max|mom-res|=1.785e-04, step=0.076
# [MEM] it=13200 max|mom-res|=1.766e-04, step=0.0749
# [MEM] it=13400 max|mom-res|=1.748e-04, step=0.0738
# [MEM] it=13600 max|mom-res|=1.731e-04, step=0.0727
# [MEM] it=13800 max|mom-res|=1.714e-04, step=0.0716
# [MEM] it=14000 max|mom-res|=1.698e-04, step=0.0705
# [MEM] it=14200 max|mom-res|=1.683e-04, step=0.0694
# [MEM] it=14400 max|mom-res|=1.668e-04, step=0.0684
# [MEM] it=14600 max|mom-res|=1.653e-04, step=0.0674
# [MEM] it=14800 max|mom-res|=1.639e-04, step=0.0664
# [MEM] it=15000 max|mom-res|=1.625e-04, step=0.0654
# [MEM] it=15200 max|mom-res|=1.612e-04, step=0.0644
# [MEM] it=15400 max|mom-res|=1.599e-04, step=0.0634
# [MEM] it=15600 max|mom-res|=1.587e-04, step=0.0625
# [MEM] it=15800 max|mom-res|=1.575e-04, step=0.0615
# [MEM] it=16000 max|mom-res|=1.563e-04, step=0.0606
# [MEM] it=16200 max|mom-res|=1.552e-04, step=0.0597
# [MEM] it=16400 max|mom-res|=1.541e-04, step=0.0588
# [MEM] it=16600 max|mom-res|=1.530e-04, step=0.0579
# [MEM] it=16800 max|mom-res|=1.519e-04, step=0.057
# [MEM] it=17000 max|mom-res|=1.509e-04, step=0.0562
# [MEM] it=17200 max|mom-res|=1.500e-04, step=0.0553
# [MEM] it=17400 max|mom-res|=1.490e-04, step=0.0545
# [MEM] it=17600 max|mom-res|=1.481e-04, step=0.0537
# [MEM] it=17800 max|mom-res|=1.472e-04, step=0.0529
# [MEM] it=18000 max|mom-res|=1.463e-04, step=0.0521
# [MEM] it=18200 max|mom-res|=1.454e-04, step=0.0513
# [MEM] it=18400 max|mom-res|=1.446e-04, step=0.0506
# [MEM] it=18600 max|mom-res|=1.438e-04, step=0.0498
# [MEM] it=18800 max|mom-res|=1.430e-04, step=0.049
# [MEM] it=19000 max|mom-res|=1.422e-04, step=0.0483
# [MEM] it=19200 max|mom-res|=1.415e-04, step=0.0476
# [MEM] it=19400 max|mom-res|=1.407e-04, step=0.0469
# [MEM] it=19600 max|mom-res|=1.400e-04, step=0.0462
# [MEM] it=19800 max|mom-res|=1.393e-04, step=0.0455
# [MEM] it=20000 max|mom-res|=1.386e-04, step=0.0448
# [MEM] hit max_iter=20000, best max|mom-res|=1.386e-04
# Discrete energy shape: (3000,)
# DEL labels shape: (3000,)
# /Users/tranminhtriet/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py:1223: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# ## 3. Continuous energy landscape (CEL) model

# %%
cel = ContinuousEnergyLandscape(
    hidden_channels=64,
    rank=32,
    delta=0.10,
    eps=1e-2,
    lambda_reg=1e-2,
    lr=1e-3,
    weight_decay=0.0,
    max_epochs=300,
    clip_grad=1.0,
    verbose=True,
    device="cpu",
    seed=seed,
)

out = cel.fit(X)
E_cel = cel.predict_energy(X)
print("CEL energy shape:", E_cel.shape)

S = cel.S_
eigvals, eigvecs = np.linalg.eigh(S)
v_top = eigvecs[:, np.argmax(eigvals)]
z_cel = (X @ v_top).reshape(-1, 1)

F_cel = np.hstack([E_cel.reshape(-1, 1), z_cel])
km_cel = KMeans(n_clusters=K, random_state=seed)
g_cel = km_cel.fit_predict(F_cel)
print("CEL labels shape:", g_cel.shape)
# Out:
# [epoch 0000] loss=338991.343750
# [epoch 0100] loss=16507.648438
# [epoch 0200] loss=5400.143066
# [epoch 0299] loss=2717.717773
# CEL energy shape: (3000,)
# CEL labels shape: (3000,)

# %% [markdown]
# ## 4. Metrics: BR, TMA, SDA

# %%
metrics_del = compute_metrics_all(g_true, g_del, K=K, P_true=P_true, X=X)
metrics_cel = compute_metrics_all(g_true, g_cel, K=K, P_true=P_true, X=X)

print("DEL metrics:", metrics_del)
print("CEL metrics:", metrics_cel)

print("DEL ARI:", adjusted_rand_score(g_true, g_del))
print("CEL ARI:", adjusted_rand_score(g_true, g_cel))
# Out:
# DEL metrics: {'BR_ARI': 0.0362001226688772, 'TMA': 0.8017874277755512, 'SDA': 0.879747818376874}
# CEL metrics: {'BR_ARI': 0.09561992358962867, 'TMA': 0.8952182135625999, 'SDA': 0.9375414473966706}
# DEL ARI: 0.0362001226688772
# CEL ARI: 0.09561992358962867
